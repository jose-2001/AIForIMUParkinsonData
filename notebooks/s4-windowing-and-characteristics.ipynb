# %%
import pandas as pd
import numpy as np
import warnings
from scipy.stats import moment, skew, kurtosis

from src.settings import ROOT_DIR
from src.preprocessing.get_anon_id import get_anon_id
from src.utils.data_split import save_and_split

# %%
data: pd.DataFrame = pd.read_pickle(ROOT_DIR / 'data' / 'processed' / 'anon_imu_data_time_series_cleaned.pkl')

# %%
data.head()
# Out:
#   anon_id        date_measure  time_stamp  imu_gyroX_right  imu_gyroY_right  \
# 0       9  2023-9-29-11-53-21         0.0      -721.682708        15.593227
# 1       9  2023-9-29-11-53-21        20.0      -670.260115       106.966612
# 2       9  2023-9-29-11-53-21        39.0     -1256.346678       154.354034
# 3       9  2023-9-29-11-53-21        64.0     -2645.955791       139.340391
# 4       9  2023-9-29-11-53-21        83.0     -4370.713652        81.916044
#
#    imu_gyroZ_right  imu_accX_right  imu_accY_right  imu_accZ_right  \
# 0      -388.127748        9.181793        2.010050       -2.132478
# 1      -531.556509        9.330485        2.006033       -2.221657
# 2      -583.745247        9.430883        2.003482       -2.231009
# 3      -516.938939        9.452909        2.061261       -2.123366
# 4      -388.833685        9.392902        2.283368       -1.919931
#
#    imu_gyroX_left  ...  imu_angularX_left  imu_angularY_left  \
# 0     -786.340071  ...          -0.272368           0.018669
# 1     -836.277343  ...          -0.925128          -0.000353
# 2     -784.334538  ...          -1.895445          -0.033696
# 3     -575.420332  ...          -2.675410          -0.071210
# 4     -228.216868  ...          -2.836775          -0.099201
#
#    imu_angularZ_left  imu_angularX_right  imu_angularY_right  \
# 0          -0.115200           -0.873084            0.076169
# 1          -0.203227            1.159180            0.022186
# 2          -0.329384            3.761404           -0.046249
# 3          -0.420512            4.947832           -0.077489
# 4          -0.418456            3.459541           -0.044035
#
#    imu_angularZ_right  imu_angularX_spine  imu_angularY_spine  \
# 0           -0.284259           -0.598579           -0.068011
# 1           -0.128051            0.950772            0.073927
# 2            0.084440            0.040030           -0.036652
# 3            0.211777            0.153714           -0.063593
# 4            0.151183            0.325708           -0.031565
#
#    imu_angularZ_spine  PD
# 0           -0.241989   1
# 1            0.385690   1
# 2            0.075855   1
# 3            0.047170   1
# 4            0.107200   1
#
# [5 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['anon_id', 'date_measure', 'time_stamp', 'imu_gyroX_right',
#        'imu_gyroY_right', 'imu_gyroZ_right', 'imu_accX_right',
#        'imu_accY_right', 'imu_accZ_right', 'imu_gyroX_left', 'imu_gyroY_left',
#        'imu_gyroZ_left', 'imu_accX_left', 'imu_accY_left', 'imu_accZ_left',
#        'imu_gyroX_spine', 'imu_gyroY_spine', 'imu_gyroZ_spine',
#        'imu_accX_spine', 'imu_accY_spine', 'imu_accZ_spine',
#        'imu_angleX_right', 'imu_angleY_right', 'imu_angleZ_right',
#        'imu_angleX_left', 'imu_angleY_left', 'imu_angleZ_left',
#        'imu_angleX_spine', 'imu_angleY_spine', 'imu_angleZ_spine',
#        'imu_angularX_left', 'imu_angularY_left', 'imu_angularZ_left',
#        'imu_angularX_right', 'imu_angularY_right', 'imu_angularZ_right',
#        'imu_angularX_spine', 'imu_angularY_spine', 'imu_angularZ_spine', 'PD'],
#       dtype='object')

# %%
# Creamos una lista de los valores únicos de fecha como strings
fechas_unicas = data['date_measure'].astype(str).unique()
# 'fechas_unicas' contiene una lista de las fechas únicas encontradas en 'date_measure' como strings
print(fechas_unicas)
# Out:
# ['2023-9-29-11-53-21' '2023-6-22-10-28-8' '2023-6-16-14-45-43'
#  '2023-9-19-10-12-28' '2023-3-23-13-14-7' '2023-7-6-12-7-50'
#  '2023-11-7-15-14-42' '2023-2-23-15-58-22' '2023-9-30-8-42-24'
#  '2023-9-30-8-58-32' '2024-1-16-16-1-25' '2023-6-16-9-48-30'
#  '2023-6-17-8-26-3' '2023-3-17-11-12-26' '2023-3-18-13-33-51'
#  '2023-6-17-8-39-41' '2023-3-17-11-1-26' '2023-6-16-14-38-22'
#  '2023-10-5-10-2-44' '2023-3-18-10-50-25' '2023-7-6-9-33-42'
#  '2023-9-5-12-31-47' '2024-2-2-9-34-54' '2023-2-23-15-37-18'
#  '2023-6-29-10-40-43' '2023-6-22-9-54-43' '2023-9-30-9-41-22'
#  '2023-9-30-12-3-43' '2023-3-23-10-28-48' '2024-2-2-11-11-47'
#  '2024-1-30-9-6-49' '2024-1-30-10-17-23' '2024-2-15-8-52-21'
#  '2024-2-15-10-1-41' '2024-2-15-11-18-44' '2023-6-17-9-42-57'
#  '2023-8-31-9-14-29' '2023-2-23-14-11-53' '2024-2-13-15-13-47'
#  '2023-9-30-12-28-15' '2023-9-7-12-2-5' '2023-2-21-15-8-52'
#  '2023-11-21-9-17-56' '2023-9-22-14-56-19' '2023-4-11-8-49-25'
#  '2023-3-30-8-35-11' '2023-11-3-10-52-41' '2023-6-16-11-54-33'
#  '2023-9-5-8-35-35' '2024-1-18-8-4-45' '2023-4-11-11-49-7'
#  '2023-7-6-11-22-29' '2023-2-23-14-27-51' '2023-2-23-15-41-30'
#  '2023-6-16-8-43-17' '2023-6-16-9-8-37' '2023-6-17-12-40-20'
#  '2023-6-17-12-32-58' '2023-6-17-9-39-14' '2023-6-17-9-8-15'
#  '2023-2-23-15-4-53' '2023-2-21-14-58-49' '2023-9-26-11-17-32'
#  '2023-2-23-15-33-32' '2023-9-19-11-37-42' '2023-2-23-14-39-38'
#  '2024-2-14-10-6-51' '2023-2-23-15-24-22' '2024-1-18-15-8-14'
#  '2023-6-27-10-4-38' '2023-2-21-14-39-6' '2023-9-30-9-23-39'
#  '2023-11-22-9-0-39' '2023-4-11-11-53-36' '2023-8-31-15-5-5'
#  '2023-8-31-15-3-10' '2023-9-12-11-8-0' '2023-9-30-14-39-22'
#  '2023-2-23-15-52-11' '2023-9-30-9-14-42' '2023-9-30-15-56-29'
#  '2023-2-23-14-47-39' '2023-9-30-8-50-2' '2023-2-21-14-25-1'
#  '2023-2-23-15-19-20' '2023-2-21-14-19-35' '2023-3-30-10-33-1'
#  '2023-2-23-15-8-54' '2023-2-23-14-34-1' '2023-9-30-12-39-16'
#  '2023-9-26-12-5-34' '2023-2-21-14-56-0' '2023-6-27-9-58-22'
#  '2023-2-23-14-8-48' '2023-2-23-14-53-1' '2023-2-23-15-13-22'
#  '2023-9-30-11-36-47' '2023-2-23-15-16-26' '2023-6-17-9-23-26'
#  '2023-3-17-15-47-28' '2023-10-5-10-15-58' '2023-10-5-10-19-30'
#  '2023-6-16-14-55-12' '2023-6-16-15-25-24' '2023-3-18-9-35-47'
#  '2023-6-16-9-4-24' '2023-6-16-15-5-45' '2023-6-17-8-32-10'
#  '2023-3-18-11-58-2' '2023-3-18-8-26-57' '2024-2-14-9-17-26'
#  '2023-2-21-14-42-57' '2023-6-16-15-27-56' '2023-2-23-15-28-23'
#  '2024-2-14-8-58-29' '2023-2-21-14-47-26' '2023-6-22-10-6-21'
#  '2023-6-22-8-9-29' '2023-9-21-10-3-13' '2023-2-23-16-1-59'
#  '2023-9-30-16-16-50' '2023-9-30-9-49-10' '2023-11-30-19-27-32'
#  '2023-6-17-8-52-8' '2023-2-23-14-20-36' '2023-2-21-14-50-59'
#  '2023-4-11-11-40-14' '2023-2-23-14-57-53' '2023-9-14-8-32-33'
#  '2023-3-29-10-11-30' '2023-9-30-9-34-4' '2023-9-4-9-49-14'
#  '2023-2-21-14-28-50' '2023-3-18-8-47-39' '2023-3-18-8-35-24'
#  '2023-3-18-9-40-22' '2023-3-18-10-14-22' '2023-6-16-15-10-33'
#  '2023-9-30-15-43-15' '2024-2-1-15-52-49' '2024-1-25-10-18-44'
#  '2023-9-30-8-33-46' '2023-2-23-15-46-0' '2023-9-25-10-50-28'
#  '2023-2-21-14-33-14' '2023-2-23-14-43-36' '2023-9-30-14-53-12'
#  '2023-3-29-10-41-7' '2023-3-18-8-18-4' '2023-6-27-8-48-43'
#  '2023-9-30-10-5-53' '2023-6-17-10-1-30' '2023-2-21-15-2-9'
#  '2023-9-30-15-35-54' '2023-3-29-10-34-3' '2023-9-30-9-6-45'
#  '2023-9-30-15-49-43' '2023-10-5-16-34-4' '2024-1-16-16-5-34'
#  '2023-3-29-10-5-2' '2023-10-5-16-23-50' '2023-10-5-16-14-35'
#  '2023-7-11-10-15-46' '2023-9-25-8-37-55' '2023-7-11-8-52-27'
#  '2023-6-17-10-39-17']

# %% [markdown]
# # Feature Engineering Stage 1: Statistical measures
#
# In the stage 1 of the feature engineering, we will build a total of 15 simple statistical features —
# 1. mean
# 2. standard deviation
# 3. average absolute deviation
# 4. minimum value
# 5. maximum value
# 6. difference of maximum and minimum values
# 7. median
# 8. median absolute deviation
# 9. interquartile range
# 10. negative values count
# 11. positive values count
# 12. number of values above mean
# 13. number of peaks
# 14. skewness
# 15. kurtosis

# %% [markdown]
# Definir la función para calcular las medidas estadísticas de una ventana

# %%
def calcular_medidas_estadisticas(columna):
    #print(columna)
    medidas = {
        'mean': np.mean(columna),
        'std': np.std(columna),
        'mean_abs_dev': np.mean(np.abs(columna - np.mean(columna))),
        'min': np.min(columna),
        'max': np.max(columna),
        'range': np.max(columna) - np.min(columna),
        'median': np.median(columna),
        'median_abs_dev': np.median(np.abs(columna - np.median(columna))),
        'interquartile_range': np.percentile(columna, 75) - np.percentile(columna, 25),
        'negative_count': np.sum(columna < 0),
        'positive_count': np.sum(columna > 0),
        'above_mean_count': np.sum(columna > np.mean(columna)),
        'local_maxima_count': len(columna) - np.sum((columna.shift(-1) < columna) & (columna.shift(1) < columna)),
        'skewness': skew(columna),
        'kurtosis': kurtosis(columna)
    }
    #print(medidas)
    return medidas

# %% [markdown]
# Crear un nuevo DataFrame para almacenar los datos de las ventanas

# %%
columnas_sensores = ['imu_gyroX_right', 'imu_gyroY_right', 'imu_gyroZ_right', 'imu_accX_right', 'imu_accY_right', 'imu_accZ_right', 'imu_gyroX_left', 'imu_gyroY_left', 'imu_gyroZ_left', 'imu_accX_left', 'imu_accY_left', 'imu_accZ_left', 'imu_gyroX_spine', 'imu_gyroY_spine', 'imu_gyroZ_spine', 'imu_accX_spine', 'imu_accY_spine', 'imu_accZ_spine', 'imu_angleX_right', 'imu_angleY_right', 'imu_angleZ_right', 'imu_angleX_left', 'imu_angleY_left', 'imu_angleZ_left', 'imu_angleX_spine', 'imu_angleY_spine', 'imu_angleZ_spine', 'imu_angularX_left', 'imu_angularY_left', 'imu_angularZ_left', 'imu_angularX_right', 'imu_angularY_right', 'imu_angularZ_right', 'imu_angularX_spine', 'imu_angularY_spine', 'imu_angularZ_spine']
medidas_estadisticas = ['mean', 'std', 'mean_abs_dev',
                      'min', 'max', 'range', 'median', 'median_abs_dev',
                      'interquartile_range', 'negative_count', 'positive_count', 'above_mean_count',
                      'local_maxima_count', 'skewness', 'kurtosis']
def generar_nombres_columnas(columnas_sensores, medidas_estadisticas):
    nombres_columnas = ['anon_id', 'date_measure', 'window_number', 'first_timestamp']
    for columna in columnas_sensores:
        for medida in medidas_estadisticas:
            nombre_columna = f"{columna}_{medida}"
            nombres_columnas.append(nombre_columna)
    nombres_columnas.append("PD")
    return nombres_columnas

columnas_df_final=generar_nombres_columnas(columnas_sensores,medidas_estadisticas)
print(columnas_df_final)
# Out:
# ['anon_id', 'date_measure', 'window_number', 'first_timestamp', 'imu_gyroX_right_mean', 'imu_gyroX_right_std', 'imu_gyroX_right_mean_abs_dev', 'imu_gyroX_right_min', 'imu_gyroX_right_max', 'imu_gyroX_right_range', 'imu_gyroX_right_median', 'imu_gyroX_right_median_abs_dev', 'imu_gyroX_right_interquartile_range', 'imu_gyroX_right_negative_count', 'imu_gyroX_right_positive_count', 'imu_gyroX_right_above_mean_count', 'imu_gyroX_right_local_maxima_count', 'imu_gyroX_right_skewness', 'imu_gyroX_right_kurtosis', 'imu_gyroY_right_mean', 'imu_gyroY_right_std', 'imu_gyroY_right_mean_abs_dev', 'imu_gyroY_right_min', 'imu_gyroY_right_max', 'imu_gyroY_right_range', 'imu_gyroY_right_median', 'imu_gyroY_right_median_abs_dev', 'imu_gyroY_right_interquartile_range', 'imu_gyroY_right_negative_count', 'imu_gyroY_right_positive_count', 'imu_gyroY_right_above_mean_count', 'imu_gyroY_right_local_maxima_count', 'imu_gyroY_right_skewness', 'imu_gyroY_right_kurtosis', 'imu_gyroZ_right_mean', 'imu_gyroZ_right_std', 'imu_gyroZ_right_mean_abs_dev', 'imu_gyroZ_right_min', 'imu_gyroZ_right_max', 'imu_gyroZ_right_range', 'imu_gyroZ_right_median', 'imu_gyroZ_right_median_abs_dev', 'imu_gyroZ_right_interquartile_range', 'imu_gyroZ_right_negative_count', 'imu_gyroZ_right_positive_count', 'imu_gyroZ_right_above_mean_count', 'imu_gyroZ_right_local_maxima_count', 'imu_gyroZ_right_skewness', 'imu_gyroZ_right_kurtosis', 'imu_accX_right_mean', 'imu_accX_right_std', 'imu_accX_right_mean_abs_dev', 'imu_accX_right_min', 'imu_accX_right_max', 'imu_accX_right_range', 'imu_accX_right_median', 'imu_accX_right_median_abs_dev', 'imu_accX_right_interquartile_range', 'imu_accX_right_negative_count', 'imu_accX_right_positive_count', 'imu_accX_right_above_mean_count', 'imu_accX_right_local_maxima_count', 'imu_accX_right_skewness', 'imu_accX_right_kurtosis', 'imu_accY_right_mean', 'imu_accY_right_std', 'imu_accY_right_mean_abs_dev', 'imu_accY_right_min', 'imu_accY_right_max', 'imu_accY_right_range', 'imu_accY_right_median', 'imu_accY_right_median_abs_dev', 'imu_accY_right_interquartile_range', 'imu_accY_right_negative_count', 'imu_accY_right_positive_count', 'imu_accY_right_above_mean_count', 'imu_accY_right_local_maxima_count', 'imu_accY_right_skewness', 'imu_accY_right_kurtosis', 'imu_accZ_right_mean', 'imu_accZ_right_std', 'imu_accZ_right_mean_abs_dev', 'imu_accZ_right_min', 'imu_accZ_right_max', 'imu_accZ_right_range', 'imu_accZ_right_median', 'imu_accZ_right_median_abs_dev', 'imu_accZ_right_interquartile_range', 'imu_accZ_right_negative_count', 'imu_accZ_right_positive_count', 'imu_accZ_right_above_mean_count', 'imu_accZ_right_local_maxima_count', 'imu_accZ_right_skewness', 'imu_accZ_right_kurtosis', 'imu_gyroX_left_mean', 'imu_gyroX_left_std', 'imu_gyroX_left_mean_abs_dev', 'imu_gyroX_left_min', 'imu_gyroX_left_max', 'imu_gyroX_left_range', 'imu_gyroX_left_median', 'imu_gyroX_left_median_abs_dev', 'imu_gyroX_left_interquartile_range', 'imu_gyroX_left_negative_count', 'imu_gyroX_left_positive_count', 'imu_gyroX_left_above_mean_count', 'imu_gyroX_left_local_maxima_count', 'imu_gyroX_left_skewness', 'imu_gyroX_left_kurtosis', 'imu_gyroY_left_mean', 'imu_gyroY_left_std', 'imu_gyroY_left_mean_abs_dev', 'imu_gyroY_left_min', 'imu_gyroY_left_max', 'imu_gyroY_left_range', 'imu_gyroY_left_median', 'imu_gyroY_left_median_abs_dev', 'imu_gyroY_left_interquartile_range', 'imu_gyroY_left_negative_count', 'imu_gyroY_left_positive_count', 'imu_gyroY_left_above_mean_count', 'imu_gyroY_left_local_maxima_count', 'imu_gyroY_left_skewness', 'imu_gyroY_left_kurtosis', 'imu_gyroZ_left_mean', 'imu_gyroZ_left_std', 'imu_gyroZ_left_mean_abs_dev', 'imu_gyroZ_left_min', 'imu_gyroZ_left_max', 'imu_gyroZ_left_range', 'imu_gyroZ_left_median', 'imu_gyroZ_left_median_abs_dev', 'imu_gyroZ_left_interquartile_range', 'imu_gyroZ_left_negative_count', 'imu_gyroZ_left_positive_count', 'imu_gyroZ_left_above_mean_count', 'imu_gyroZ_left_local_maxima_count', 'imu_gyroZ_left_skewness', 'imu_gyroZ_left_kurtosis', 'im ...

# %%
df_ventanas = pd.DataFrame(columns=columnas_df_final)

# %% [markdown]
# Definir los parámetros para las ventanas

# %%
frecuencia_muestreo = 50  # Hz
longitud_ventana_s = 1  # segundos
overlap = 0.5  # 50%

# %% [markdown]
# Calcular la cantidad de filas por ventana y el paso de tiempo entre ventanas

# %%
filas_por_ventana = int(longitud_ventana_s * frecuencia_muestreo)
paso_tiempo = int(filas_por_ventana * (1 - overlap))

# %%
# Ignorar todos los warnings
warnings.filterwarnings("ignore")

# %%
columnas_df_final_sensores=columnas_df_final
columnas_df_final_sensores.remove('anon_id')
columnas_df_final_sensores.remove('date_measure')
columnas_df_final_sensores.remove('window_number')
columnas_df_final_sensores.remove('first_timestamp')
columnas_df_final_sensores.remove('PD')
print(columnas_df_final_sensores)
# Out:
# ['imu_gyroX_right_mean', 'imu_gyroX_right_std', 'imu_gyroX_right_mean_abs_dev', 'imu_gyroX_right_min', 'imu_gyroX_right_max', 'imu_gyroX_right_range', 'imu_gyroX_right_median', 'imu_gyroX_right_median_abs_dev', 'imu_gyroX_right_interquartile_range', 'imu_gyroX_right_negative_count', 'imu_gyroX_right_positive_count', 'imu_gyroX_right_above_mean_count', 'imu_gyroX_right_local_maxima_count', 'imu_gyroX_right_skewness', 'imu_gyroX_right_kurtosis', 'imu_gyroY_right_mean', 'imu_gyroY_right_std', 'imu_gyroY_right_mean_abs_dev', 'imu_gyroY_right_min', 'imu_gyroY_right_max', 'imu_gyroY_right_range', 'imu_gyroY_right_median', 'imu_gyroY_right_median_abs_dev', 'imu_gyroY_right_interquartile_range', 'imu_gyroY_right_negative_count', 'imu_gyroY_right_positive_count', 'imu_gyroY_right_above_mean_count', 'imu_gyroY_right_local_maxima_count', 'imu_gyroY_right_skewness', 'imu_gyroY_right_kurtosis', 'imu_gyroZ_right_mean', 'imu_gyroZ_right_std', 'imu_gyroZ_right_mean_abs_dev', 'imu_gyroZ_right_min', 'imu_gyroZ_right_max', 'imu_gyroZ_right_range', 'imu_gyroZ_right_median', 'imu_gyroZ_right_median_abs_dev', 'imu_gyroZ_right_interquartile_range', 'imu_gyroZ_right_negative_count', 'imu_gyroZ_right_positive_count', 'imu_gyroZ_right_above_mean_count', 'imu_gyroZ_right_local_maxima_count', 'imu_gyroZ_right_skewness', 'imu_gyroZ_right_kurtosis', 'imu_accX_right_mean', 'imu_accX_right_std', 'imu_accX_right_mean_abs_dev', 'imu_accX_right_min', 'imu_accX_right_max', 'imu_accX_right_range', 'imu_accX_right_median', 'imu_accX_right_median_abs_dev', 'imu_accX_right_interquartile_range', 'imu_accX_right_negative_count', 'imu_accX_right_positive_count', 'imu_accX_right_above_mean_count', 'imu_accX_right_local_maxima_count', 'imu_accX_right_skewness', 'imu_accX_right_kurtosis', 'imu_accY_right_mean', 'imu_accY_right_std', 'imu_accY_right_mean_abs_dev', 'imu_accY_right_min', 'imu_accY_right_max', 'imu_accY_right_range', 'imu_accY_right_median', 'imu_accY_right_median_abs_dev', 'imu_accY_right_interquartile_range', 'imu_accY_right_negative_count', 'imu_accY_right_positive_count', 'imu_accY_right_above_mean_count', 'imu_accY_right_local_maxima_count', 'imu_accY_right_skewness', 'imu_accY_right_kurtosis', 'imu_accZ_right_mean', 'imu_accZ_right_std', 'imu_accZ_right_mean_abs_dev', 'imu_accZ_right_min', 'imu_accZ_right_max', 'imu_accZ_right_range', 'imu_accZ_right_median', 'imu_accZ_right_median_abs_dev', 'imu_accZ_right_interquartile_range', 'imu_accZ_right_negative_count', 'imu_accZ_right_positive_count', 'imu_accZ_right_above_mean_count', 'imu_accZ_right_local_maxima_count', 'imu_accZ_right_skewness', 'imu_accZ_right_kurtosis', 'imu_gyroX_left_mean', 'imu_gyroX_left_std', 'imu_gyroX_left_mean_abs_dev', 'imu_gyroX_left_min', 'imu_gyroX_left_max', 'imu_gyroX_left_range', 'imu_gyroX_left_median', 'imu_gyroX_left_median_abs_dev', 'imu_gyroX_left_interquartile_range', 'imu_gyroX_left_negative_count', 'imu_gyroX_left_positive_count', 'imu_gyroX_left_above_mean_count', 'imu_gyroX_left_local_maxima_count', 'imu_gyroX_left_skewness', 'imu_gyroX_left_kurtosis', 'imu_gyroY_left_mean', 'imu_gyroY_left_std', 'imu_gyroY_left_mean_abs_dev', 'imu_gyroY_left_min', 'imu_gyroY_left_max', 'imu_gyroY_left_range', 'imu_gyroY_left_median', 'imu_gyroY_left_median_abs_dev', 'imu_gyroY_left_interquartile_range', 'imu_gyroY_left_negative_count', 'imu_gyroY_left_positive_count', 'imu_gyroY_left_above_mean_count', 'imu_gyroY_left_local_maxima_count', 'imu_gyroY_left_skewness', 'imu_gyroY_left_kurtosis', 'imu_gyroZ_left_mean', 'imu_gyroZ_left_std', 'imu_gyroZ_left_mean_abs_dev', 'imu_gyroZ_left_min', 'imu_gyroZ_left_max', 'imu_gyroZ_left_range', 'imu_gyroZ_left_median', 'imu_gyroZ_left_median_abs_dev', 'imu_gyroZ_left_interquartile_range', 'imu_gyroZ_left_negative_count', 'imu_gyroZ_left_positive_count', 'imu_gyroZ_left_above_mean_count', 'imu_gyroZ_left_local_maxima_count', 'imu_gyroZ_left_skewness', 'imu_gyroZ_left_kurtosis', 'imu_accX_left_mean', 'imu_accX_left_std', 'imu_accX_left_mean_abs ...

# %%
# Iterar sobre los datos originales en el DataFrame
window_number = 1
for i in range(0, len(data) - filas_por_ventana + 1, paso_tiempo):
    # Seleccionar la primera fila de cada ventana
    primera_fila_ventana = data.iloc[i]

    # Seleccionar los valores relevantes de la fila
    anon_id = primera_fila_ventana['anon_id']
    date_measure = primera_fila_ventana['date_measure']
    PD = primera_fila_ventana['PD']
    first_timestamp = primera_fila_ventana['time_stamp']

    # Seleccionar la ventana incluyendo tanto los valores de los sensores como los metadatos
    ventana = data.iloc[i:i + filas_por_ventana]

    # Verificar si los valores en la primera y última fila de la ventana son iguales
    while not ventana.iloc[0][['anon_id', 'date_measure', 'PD']].equals(
            ventana.iloc[-1][['anon_id', 'date_measure', 'PD']]):
        ventana = ventana.iloc[:-1]  # Reducir la longitud de la ventana eliminando la última fila

    # Eliminar los valores de 'anon_id', 'date_measure' y 'PD' de la ventana antes de calcular las medidas estadísticas
    ventana_valores_sensor = ventana.drop(['anon_id', 'date_measure', 'time_stamp', 'PD'], axis=1)

    # Calcular las medidas estadísticas de la ventana para cada columna
    datos_ventana = {
        'anon_id': anon_id,
        'date_measure': date_measure,
        'window_number': window_number,
        'first_timestamp': first_timestamp,
        'PD': PD
    }
    for sensor_col in ventana_valores_sensor.columns:
        medidas = calcular_medidas_estadisticas(ventana_valores_sensor[sensor_col])
        for medida, medida_valor in medidas.items():
            nombre_columna = f"{sensor_col}_{medida}"
            datos_ventana[nombre_columna] = medida_valor

    # Añadir los datos de la ventana al DataFrame
    df_ventanas = pd.concat([df_ventanas, pd.DataFrame(datos_ventana, index=[0])], ignore_index=True)

    window_number += 1

# %%
# Restaurar el comportamiento predeterminado de los warnings
warnings.filterwarnings("default")

# %%
# Mostrar las primeras filas del DataFrame de ventanas
print(df_ventanas.head())
# Out:
#   anon_id        date_measure window_number  first_timestamp  \
# 0       9  2023-9-29-11-53-21             1              0.0
# 1       9  2023-9-29-11-53-21             2            532.0
# 2       9  2023-9-29-11-53-21             3           1029.0
# 3       9  2023-9-29-11-53-21             4           1587.0
# 4       9  2023-9-29-11-53-21             5           2121.0
#
#    imu_gyroX_right_mean  imu_gyroX_right_std  imu_gyroX_right_mean_abs_dev  \
# 0            344.527504          2066.933206                   1375.765062
# 1            -19.660417          1231.834050                    996.842663
# 2            312.616200          1460.410867                   1236.003103
# 3            504.363670          1551.660978                   1195.522472
# 4           -775.488526          1733.126911                   1391.358979
#
#    imu_gyroX_right_min  imu_gyroX_right_max  imu_gyroX_right_range  ...  \
# 0         -5573.486673          4888.726779           10462.213452  ...
# 1         -3009.424803          2401.841438            5411.266241  ...
# 2         -3009.424803          3060.657605            6070.082407  ...
# 3         -3127.877221          3060.657605            6188.534825  ...
# 4         -5263.676001          1333.368845            6597.044846  ...
#
#    imu_angularZ_spine_median  imu_angularZ_spine_median_abs_dev  \
# 0                  -0.006599                           0.143210
# 1                  -0.126084                           0.169421
# 2                  -0.138009                           0.273426
# 3                  -0.128971                           0.406405
# 4                  -0.094389                           0.358339
#
#    imu_angularZ_spine_interquartile_range imu_angularZ_spine_negative_count  \
# 0                                0.292160                                25
# 1                                0.390708                                33
# 2                                0.489978                                35
# 3                                0.800999                                32
# 4                                0.678456                                29
#
#   imu_angularZ_spine_positive_count imu_angularZ_spine_above_mean_count  \
# 0                                25                                  21
# 1                                17                                  15
# 2                                15                                  15
# 3                                18                                  19
# 4                                21                                  19
#
#   imu_angularZ_spine_local_maxima_count  imu_angularZ_spine_skewness  \
# 0                                    34                     0.590057
# 1                                    34                     5.157702
# 2                                    34                     2.595318
# 3                                    36                     1.323667
# 4                                    38                     0.793148
#
#    imu_angularZ_spine_kurtosis  PD
# 0                     0.414016   1
# 1                    30.368313   1
# 2                    10.500248   1
# 3                     3.389447   1
# 4                     3.870439   1
#
# [5 rows x 545 columns]

# %%
df_ventanas.to_pickle(ROOT_DIR / 'data' / 'processed'/'anon_imu_data_features.pkl')
df_ventanas.to_csv(ROOT_DIR / 'data' / 'processed'/'anon_imu_data_features.csv')

# %%
#df_ventanas: pd.DataFrame = pd.read_pickle(ROOT_DIR / 'data' / 'processed' / 'anon_imu_data_features.csv')

# %%
print(df_ventanas.first_timestamp.tolist())
# Out:
# [0.0, 532.0, 1029.0, 1587.0, 2121.0, 2692.0, 3221.0, 3723.0, 4262.0, 4763.0, 5260.0, 5762.0, 6287.0, 6788.0, 7315.0, 7888.0, 8460.0, 9032.0, 9533.0, 10054.0, 10581.0, 11179.0, 11764.0, 12261.0, 12806.0, 13386.0, 13924.0, 14420.0, 14967.0, 15467.0, 16015.0, 16553.0, 17050.0, 17551.0, 18052.0, 18553.0, 19054.0, 19551.0, 20052.0, 20553.0, 21073.0, 21574.0, 22107.0, 22608.0, 23106.0, 23607.0, 24128.0, 24629.0, 25129.0, 25651.0, 26152.0, 26653.0, 27193.0, 27728.0, 28261.0, 28762.0, 29263.0, 29837.0, 30338.0, 30838.0, 31353.0, 31855.0, 32352.0, 32852.0, 33353.0, 33899.0, 34399.0, 34897.0, 35429.0, 35930.0, 36426.0, 36984.0, 37498.0, 37999.0, 38514.0, 39042.0, 39543.0, 40044.0, 40560.0, 41073.0, 41588.0, 42161.0, 42693.0, 43194.0, 43760.0, 44258.0, 44758.0, 45259.0, 45759.0, 46256.0, 46757.0, 47258.0, 47759.0, 48260.0, 48783.0, 49283.0, 49805.0, 50305.0, 50801.0, 51302.0, 51803.0, 52304.0, 52805.0, 53302.0, 53840.0, 54343.0, 54844.0, 55345.0, 55842.0, 56343.0, 56844.0, 57370.0, 57866.0, 58367.0, 58868.0, 59369.0, 59870.0, 60367.0, 60869.0, 61369.0, 61870.0, 62367.0, 62867.0, 63368.0, 63869.0, 64370.0, 64867.0, 65368.0, 65870.0, 66370.0, 66867.0, 67368.0, 67870.0, 68409.0, 68910.0, 69411.0, 69907.0, 70408.0, 70909.0, 71410.0, 71907.0, 72408.0, 72909.0, 73410.0, 73911.0, 74451.0, 74947.0, 75474.0, 75975.0, 76510.0, 77011.0, 77576.0, 78072.0, 78573.0, 79075.0, 79575.0, 80076.0, 80574.0, 81086.0, 81582.0, 82083.0, 82584.0, 83085.0, 83586.0, 84108.0, 84609.0, 85110.0, 85611.0, 86108.0, 86609.0, 87110.0, 87611.0, 88107.0, 88608.0, 89109.0, 89610.0, 90111.0, 90608.0, 91109.0, 91631.0, 92131.0, 92640.0, 93141.0, 93642.0, 94183.0, 94684.0, 95210.0, 95711.0, 96265.0, 96766.0, 97267.0, 97764.0, 98284.0, 98785.0, 99286.0, 99787.0, 100283.0, 100784.0, 101299.0, 101800.0, 102301.0, 102802.0, 103299.0, 103845.0, 104366.0, 104887.0, 105387.0, 105884.0, 106416.0, 106931.0, 107432.0, 107933.0, 108430.0, 108930.0, 109431.0, 109932.0, 110429.0, 110930.0, 111438.0, 111958.0, 112531.0, 113110.0, 113687.0, 114188.0, 114685.0, 115186.0, 115720.0, 116252.0, 116752.0, 117287.0, 117788.0, 118284.0, 118800.0, 119318.0, 119832.0, 120330.0, 120869.0, 121396.0, 452.0, 1478.0, 2505.0, 3530.0, 4555.0, 5582.0, 6608.0, 7634.0, 8660.0, 9685.0, 10711.0, 11736.0, 12762.0, 13788.0, 14813.0, 15840.0, 16865.0, 17890.0, 18918.0, 19943.0, 20970.0, 21995.0, 23019.0, 24046.0, 25071.0, 26098.0, 27124.0, 28149.0, 29175.0, 30200.0, 31226.0, 32252.0, 33277.0, 34304.0, 35329.0, 36355.0, 37382.0, 38407.0, 39433.0, 40459.0, 41485.0, 42511.0, 43537.0, 44563.0, 45589.0, 46615.0, 47640.0, 48666.0, 49692.0, 50721.0, 51770.0, 52799.0, 53824.0, 54850.0, 55876.0, 56902.0, 57929.0, 58954.0, 59980.0, 61006.0, 62038.0, 63064.0, 64090.0, 65116.0, 66141.0, 67168.0, 68193.0, 69220.0, 70246.0, 71271.0, 72297.0, 73324.0, 74349.0, 75376.0, 76401.0, 77427.0, 78453.0, 79478.0, 80506.0, 81531.0, 82557.0, 83583.0, 84608.0, 85635.0, 86660.0, 87685.0, 88712.0, 89737.0, 90763.0, 91790.0, 92815.0, 93842.0, 94867.0, 95893.0, 96919.0, 97945.0, 98971.0, 99996.0, 101021.0, 102047.0, 103072.0, 104098.0, 105124.0, 106150.0, 107176.0, 108201.0, 109227.0, 110254.0, 111280.0, 112305.0, 113331.0, 114357.0, 115383.0, 116408.0, 117434.0, 118460.0, 119486.0, 120512.0, 121538.0, 122563.0, 123589.0, 124615.0, 125641.0, 126667.0, 127693.0, 128719.0, 129745.0, 130770.0, 131796.0, 132822.0, 133847.0, 134874.0, 135899.0, 136925.0, 137951.0, 138976.0, 140003.0, 903.0, 1930.0, 2955.0, 3981.0, 5007.0, 6032.0, 7059.0, 8084.0, 9109.0, 10135.0, 11160.0, 12185.0, 13211.0, 14237.0, 15268.0, 16292.0, 17318.0, 18344.0, 19370.0, 20395.0, 21421.0, 22448.0, 23474.0, 24499.0, 25525.0, 26551.0, 27576.0, 28602.0, 29627.0, 30653.0, 31679.0, 32704.0, 33729.0, 34755.0, 35781.0, 36807.0, 37832.0, 38858.0, 39884.0, 40912.0, 41937.0, 42963.0, 43989.0, 45016.0, 46041.0, 47066.0, 48092.0, 360.0, 901.0, 1420.0, 1966.0, 2467.0, 2964.0, 3511.0, 4050.0, 4603.0, 5103.0, 5600.0, 6102.0, 6602.0, 7111.0, 7612.0, 8126.0, 8704.0, 9200.0, 9700.0, 10216.0, 10749 ...
