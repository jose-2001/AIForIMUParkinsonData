# %% [markdown]
# # Metrics of ASA

# %% [markdown]
# ## Required Imports

# %%
import pickle

from src.settings import ROOT_DIR
from src.evaluation.model_metrics_report import print_sklearn_model_metrics

# %% [markdown]
# ## Data Loading

# %%
test_data_path = ROOT_DIR / 'data' / 'processed' / 'asa-features' / 'test.pkl'

with open(test_data_path, 'rb') as file:
    test_data = pickle.load(file)

# %%
len(test_data)
# Out:
# 1975

# %%
features = test_data.columns.tolist()
target = features.pop(-1)

X_test, y_test = test_data[features], test_data[target]

# %% [markdown]
# ## Model loading

# %%
results_path = ROOT_DIR / 'results' / 'models' / 'asa-features'

# %%
with open(results_path / 'model.svm.pkl', 'rb') as file:
    svm = pickle.load(file)

with open(results_path / 'model.knn.pkl', 'rb') as file:
    knn = pickle.load(file)

with open(results_path / 'model.gboost.pkl', 'rb') as file:
    gboost = pickle.load(file)

# %% [markdown]
# ## Test metrics

# %%
print_sklearn_model_metrics(svm, X_test, y_test.to_numpy())
# Out:
# Accuracy: 0.8091139240506329
# 0.6154501672068071
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.82      1075
#            1       0.79      0.79      0.79       900
#
#     accuracy                           0.81      1975
#    macro avg       0.81      0.81      0.81      1975
# weighted avg       0.81      0.81      0.81      1975
#
# AUC-ROC: 0.8079198966408269
# AUC-PR: 0.8382142253483997

# %%
print_sklearn_model_metrics(knn, X_test, y_test)
# Out:
# Accuracy: 0.8374683544303797
# 0.6723347072732676
#               precision    recall  f1-score   support
#
#            0       0.85      0.85      0.85      1075
#            1       0.82      0.82      0.82       900
#
#     accuracy                           0.84      1975
#    macro avg       0.84      0.84      0.84      1975
# weighted avg       0.84      0.84      0.84      1975
#
# AUC-ROC: 0.8361369509043928
# AUC-PR: 0.8623272850440167

# %%
print_sklearn_model_metrics(gboost, X_test, y_test)
# Out:
# Accuracy: 0.8212658227848101
# 0.6386243180551776
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1075
#            1       0.82      0.79      0.80       900
#
#     accuracy                           0.82      1975
#    macro avg       0.82      0.82      0.82      1975
# weighted avg       0.82      0.82      0.82      1975
#
# AUC-ROC: 0.818359173126615
# AUC-PR: 0.8493663342726021
