# %% [markdown]
# # Metrics of Dyskynesias

# %% [markdown]
# ## Required Imports

# %%
import pickle

from src.settings import ROOT_DIR
from src.evaluation.model_metrics_report import print_sklearn_model_metrics

# %% [markdown]
# ## Data Loading

# %%
test_data_path = ROOT_DIR / 'data' / 'processed' / 'dysk-features' / 'test.pkl'

with open(test_data_path, 'rb') as file:
    test_data = pickle.load(file)

# %%
len(test_data)
# Out:
# 1257

# %%
features = test_data.columns.tolist()
target = features.pop(-1)

X_test, y_test = test_data[features], test_data[target]

# %% [markdown]
# ## Model loading

# %%
results_path = ROOT_DIR / 'results' / 'models' / 'dysk-features'

# %%
with open(results_path / 'model.svm.pkl', 'rb') as file:
    svm = pickle.load(file)

with open(results_path / 'model.knn.pkl', 'rb') as file:
    knn = pickle.load(file)

with open(results_path / 'model.gboost.pkl', 'rb') as file:
    gboost = pickle.load(file)

# %% [markdown]
# ## Test metrics

# %%
print_sklearn_model_metrics(svm, X_test, y_test.to_numpy())
# Out:
# Accuracy: 0.9506762132060461
# 0.4468214985378042
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      1169
#            1       0.96      0.31      0.47        88
#
#     accuracy                           0.95      1257
#    macro avg       0.96      0.65      0.72      1257
# weighted avg       0.95      0.95      0.94      1257
#
# AUC-ROC: 0.6529813749125127
# AUC-PR: 0.6598160689747803

# %%
print_sklearn_model_metrics(knn, X_test, y_test)
# Out:
# Accuracy: 0.9809069212410502
# 0.8399133978604177
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1169
#            1       0.94      0.77      0.85        88
#
#     accuracy                           0.98      1257
#    macro avg       0.96      0.88      0.92      1257
# weighted avg       0.98      0.98      0.98      1257
#
# AUC-ROC: 0.8846527723773232
# AUC-PR: 0.8665413080687543

# %%
print_sklearn_model_metrics(gboost, X_test, y_test)
# Out:
# Accuracy: 0.9626093874303898
# 0.6569821114420582
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98      1169
#            1       0.86      0.56      0.68        88
#
#     accuracy                           0.96      1257
#    macro avg       0.91      0.77      0.83      1257
# weighted avg       0.96      0.96      0.96      1257
#
# AUC-ROC: 0.7749873629364646
# AUC-PR: 0.7237467788042464
