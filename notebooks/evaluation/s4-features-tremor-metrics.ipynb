# %% [markdown]
# # Metrics of Tremor

# %% [markdown]
# ## Required Imports

# %%
import pickle

from src.settings import ROOT_DIR
from src.evaluation.model_metrics_report import print_sklearn_model_metrics

# %% [markdown]
# ## Data Loading

# %%
test_data_path = ROOT_DIR / 'data' / 'processed' / 'tremor-features' / 'test.pkl'

with open(test_data_path, 'rb') as file:
    test_data = pickle.load(file)

# %%
len(test_data)
# Out:
# 1655

# %%
features = test_data.columns.tolist()
target = features.pop(-1)

X_test, y_test = test_data[features], test_data[target]

# %% [markdown]
# ## Model loading

# %%
results_path = ROOT_DIR / 'results' / 'models' / 'tremor-features'

# %%
with open(results_path / 'model.svm.pkl', 'rb') as file:
    svm = pickle.load(file)

with open(results_path / 'model.knn.pkl', 'rb') as file:
    knn = pickle.load(file)

with open(results_path / 'model.gboost.pkl', 'rb') as file:
    gboost = pickle.load(file)

# %% [markdown]
# ## Test metrics

# %%
print_sklearn_model_metrics(svm, X_test, y_test.to_numpy())
# Out:
# Accuracy: 0.8749244712990937
# 0.283988521578471
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93      1402
#            1       0.94      0.19      0.32       253
#
#     accuracy                           0.87      1655
#    macro avg       0.91      0.60      0.63      1655
# weighted avg       0.88      0.87      0.84      1655
#
# AUC-ROC: 0.5957680445213782
# AUC-PR: 0.6296232107574549

# %%
print_sklearn_model_metrics(knn, X_test, y_test)
# Out:
# Accuracy: 0.8755287009063444
# 0.3368178617419011
#               precision    recall  f1-score   support
#
#            0       0.88      0.99      0.93      1402
#            1       0.78      0.26      0.39       253
#
#     accuracy                           0.88      1655
#    macro avg       0.83      0.62      0.66      1655
# weighted avg       0.87      0.88      0.85      1655
#
# AUC-ROC: 0.6220390971677953
# AUC-PR: 0.5768223461655273

# %%
print_sklearn_model_metrics(gboost, X_test, y_test)
# Out:
# Accuracy: 0.9057401812688822
# 0.5313061632023237
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.95      1402
#            1       0.92      0.42      0.58       253
#
#     accuracy                           0.91      1655
#    macro avg       0.91      0.71      0.76      1655
# weighted avg       0.91      0.91      0.89      1655
#
# AUC-ROC: 0.7062764655799451
# AUC-PR: 0.7147666073582271
